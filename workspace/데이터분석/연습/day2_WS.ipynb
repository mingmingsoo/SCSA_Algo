# %% [markdown]
# # 효자동 인구 분포와 비슷한 동네 찾기

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## 모듈 import

# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML
display(HTML('<style>.container {width : 100%; !important;}</style>'))
# Out:
# <style>.container {width : 100%; !important;}</style>

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## 데이터 로드

# %%
# 202201_202201_연령별인구현황_월간.csv 파일을 읽으세요. (encoding = 'cp949', thousands = ',')
df = pd.read_csv("../data/202201_202201_연령별인구현황_월간.csv", encoding = 'cp949', thousands = ',')
df
# Out:
#                               행정구역  2022년01월_계_총인구수  2022년01월_계_연령구간인구수  \
# 0              서울특별시  (1100000000)          9505926             9505926
# 1           서울특별시 종로구 (1111000000)           144543              144543
# 2      서울특별시 종로구 청운효자동(1111051500)            11941               11941
# 3        서울특별시 종로구 사직동(1111053000)             9349                9349
# 4        서울특별시 종로구 삼청동(1111054000)             2457                2457
# ...                            ...              ...                 ...
# 3865  제주특별자치도 서귀포시 서홍동(5013058000)            11149               11149
# 3866  제주특별자치도 서귀포시 대륜동(5013059000)            15386               15386
# 3867  제주특별자치도 서귀포시 대천동(5013060000)            13809               13809
# 3868  제주특별자치도 서귀포시 중문동(5013061000)            11959               11959
# 3869  제주특별자치도 서귀포시 예래동(5013062000)             3911                3911
#
#       2022년01월_계_0세  2022년01월_계_1세  2022년01월_계_2세  2022년01월_계_3세  \
# 0             42645          44681          48381          51247
# 1               469            477            576            544
# 2                42             52             53             57
# 3                42             25             44             35
# 4                 5              6              5              5
# ...             ...            ...            ...            ...
# 3865             73             71             96             94
# 3866            112            127            167            142
# 3867             80             99            132            120
# 3868             64             72             86             79
# 3869             13             15             11             23
#
#       2022년01월_계_4세  2022년01월_계_5세  2022년01월_계_6세  ...  2022년01월_계_91세  \
# 0             55310          62274          67281  ...            8058
# 1               638            746            855  ...             173
# 2                67             72            101  ...               9
# 3                52             67             81  ...              11
# 4                16              6             19  ...               4
# ...             ...            ...            ...  ...             ...
# 3865            121            143            164  ...               9
# 3866            159            176            168  ...              17
# 3867            185            211            193  ...              15
# 3868             74             91            112  ...              14
# 3869             21             21             34  ...               7
#
#       2022년01월_계_92세  2022년01월_계_93세  2022년01월_계_94세  2022년01월_계_95세  \
# 0               6842            5404            4061            2714
# 1                147             110              92              77
# 2                 10              10               5               5
# 3                 18               9               8               6
# 4                  5               4               2               2
# ...              ...             ...             ...             ...
# 3865               6              10               0               1
# 3866              10               8               9               4
# 3867               9               9               6               6
# 3868              14               9               5               2
# 3869              11               5               3               3
#
#       2022년01월_계_96세  2022년01월_계_97세  2022년01월_계_98세  2022년01월_계_99세  \
# 0               1866            1368            1237             857
# 1                 49              29              24              26
# 2                  5               2               3               2
# 3                  8               4               2               2
# 4                  0               2               0               2
# ...              ...             ...             ...             ...
# 3865               2               1               1               2
# 3866               3               1               5               3
# 3867               2               1               1               3
# 3868               4               1               2               0
# 3869               1               0               4               1
#
#       2022년01월_계_100세 이상
# 0                   1683
# 1                     35
# 2                      2
# 3                      1
# 4                      2
# ...                  ...
# 3865                   4
# 3866                   5
# 3867                   3
# 3868                   4
# 3869                   0
#
# [3870 rows x 104 columns]

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## 데이터 정보 조회

# %%
df1 = pd.DataFrame({
    "A":[1,2],
    "B":[3,4],
    "C":["X","Y"],
    "D":["Z",np.nan]}, index =["a","b"])
df1

df2 = pd.DataFrame({
    "A":[5,6],
    "B":[7,8],
    "C":["Z","W"]}
    , index =["c","d"])
df2
# Out:
#    A  B  C
# c  5  7  Z
# d  6  8  W

# %%
df1
# Out:
#    A  B  C    D
# a  1  3  X    Z
# b  2  4  Y  NaN

# %%
df2
# Out:
#    A  B  C
# c  5  7  Z
# d  6  8  W

# %%
pd.concat([df1,df2],axis = 0, join = "inner")
# Out:
#    A  B  C
# a  1  3  X
# b  2  4  Y
# c  5  7  Z
# d  6  8  W

# %%
# 행과 열의 개수를 구하세요.
df.shape
# Out:
# (3870, 104)

# %%
# 컬럼명을 조회하세요.
df.columns
# Out:
# Index(['행정구역', '2022년01월_계_총인구수', '2022년01월_계_연령구간인구수', '2022년01월_계_0세',
#        '2022년01월_계_1세', '2022년01월_계_2세', '2022년01월_계_3세', '2022년01월_계_4세',
#        '2022년01월_계_5세', '2022년01월_계_6세',
#        ...
#        '2022년01월_계_91세', '2022년01월_계_92세', '2022년01월_계_93세', '2022년01월_계_94세',
#        '2022년01월_계_95세', '2022년01월_계_96세', '2022년01월_계_97세', '2022년01월_계_98세',
#        '2022년01월_계_99세', '2022년01월_계_100세 이상'],
#       dtype='object', length=104)

# %%
# 세번째 컬럼 명 부터 슬라이싱하여 cols에 저장하세요. (인구 분포를 확인할 컬럼)
cols = df.columns[3:]
cols
# Out:
# Index(['2022년01월_계_0세', '2022년01월_계_1세', '2022년01월_계_2세', '2022년01월_계_3세',
#        '2022년01월_계_4세', '2022년01월_계_5세', '2022년01월_계_6세', '2022년01월_계_7세',
#        '2022년01월_계_8세', '2022년01월_계_9세',
#        ...
#        '2022년01월_계_91세', '2022년01월_계_92세', '2022년01월_계_93세', '2022년01월_계_94세',
#        '2022년01월_계_95세', '2022년01월_계_96세', '2022년01월_계_97세', '2022년01월_계_98세',
#        '2022년01월_계_99세', '2022년01월_계_100세 이상'],
#       dtype='object', length=101)

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## 데이터 타입 변경

# %%
# 각 열 별 데이터 타입을 조회하세요.
df.dtypes
# Out:
# 행정구역                  object
# 2022년01월_계_총인구수        int64
# 2022년01월_계_연령구간인구수     int64
# 2022년01월_계_0세          int64
# 2022년01월_계_1세          int64
#                        ...
# 2022년01월_계_96세         int64
# 2022년01월_계_97세         int64
# 2022년01월_계_98세         int64
# 2022년01월_계_99세         int64
# 2022년01월_계_100세 이상     int64
# Length: 104, dtype: object

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## 효자동과 사직동 인구 분포의 차이
# - 두 지역의 각 열 별 차이를 구한 뒤
# - 각 차이의 제곱의 합을 더한 값을 error라 정의한다.
# - 두 지역의 error가 작을수록 인구 분포가 비슷하다고 정의한다.

# %%
# 2번 행(효자동 행), cols 컬럼을 선택하여 flag에 저장하세요.
flag = df.loc[2, cols]
flag
# Out:
# 2022년01월_계_0세         42
# 2022년01월_계_1세         52
# 2022년01월_계_2세         53
# 2022년01월_계_3세         57
# 2022년01월_계_4세         67
#                       ..
# 2022년01월_계_96세         5
# 2022년01월_계_97세         2
# 2022년01월_계_98세         3
# 2022년01월_계_99세         2
# 2022년01월_계_100세 이상     2
# Name: 2, Length: 101, dtype: object

# %%
df
# Out:
#                               행정구역  2022년01월_계_총인구수  2022년01월_계_연령구간인구수  \
# 0              서울특별시  (1100000000)          9505926             9505926
# 1           서울특별시 종로구 (1111000000)           144543              144543
# 2      서울특별시 종로구 청운효자동(1111051500)            11941               11941
# 3        서울특별시 종로구 사직동(1111053000)             9349                9349
# 4        서울특별시 종로구 삼청동(1111054000)             2457                2457
# ...                            ...              ...                 ...
# 3865  제주특별자치도 서귀포시 서홍동(5013058000)            11149               11149
# 3866  제주특별자치도 서귀포시 대륜동(5013059000)            15386               15386
# 3867  제주특별자치도 서귀포시 대천동(5013060000)            13809               13809
# 3868  제주특별자치도 서귀포시 중문동(5013061000)            11959               11959
# 3869  제주특별자치도 서귀포시 예래동(5013062000)             3911                3911
#
#       2022년01월_계_0세  2022년01월_계_1세  2022년01월_계_2세  2022년01월_계_3세  \
# 0             42645          44681          48381          51247
# 1               469            477            576            544
# 2                42             52             53             57
# 3                42             25             44             35
# 4                 5              6              5              5
# ...             ...            ...            ...            ...
# 3865             73             71             96             94
# 3866            112            127            167            142
# 3867             80             99            132            120
# 3868             64             72             86             79
# 3869             13             15             11             23
#
#       2022년01월_계_4세  2022년01월_계_5세  2022년01월_계_6세  ...  2022년01월_계_91세  \
# 0             55310          62274          67281  ...            8058
# 1               638            746            855  ...             173
# 2                67             72            101  ...               9
# 3                52             67             81  ...              11
# 4                16              6             19  ...               4
# ...             ...            ...            ...  ...             ...
# 3865            121            143            164  ...               9
# 3866            159            176            168  ...              17
# 3867            185            211            193  ...              15
# 3868             74             91            112  ...              14
# 3869             21             21             34  ...               7
#
#       2022년01월_계_92세  2022년01월_계_93세  2022년01월_계_94세  2022년01월_계_95세  \
# 0               6842            5404            4061            2714
# 1                147             110              92              77
# 2                 10              10               5               5
# 3                 18               9               8               6
# 4                  5               4               2               2
# ...              ...             ...             ...             ...
# 3865               6              10               0               1
# 3866              10               8               9               4
# 3867               9               9               6               6
# 3868              14               9               5               2
# 3869              11               5               3               3
#
#       2022년01월_계_96세  2022년01월_계_97세  2022년01월_계_98세  2022년01월_계_99세  \
# 0               1866            1368            1237             857
# 1                 49              29              24              26
# 2                  5               2               3               2
# 3                  8               4               2               2
# 4                  0               2               0               2
# ...              ...             ...             ...             ...
# 3865               2               1               1               2
# 3866               3               1               5               3
# 3867               2               1               1               3
# 3868               4               1               2               0
# 3869               1               0               4               1
#
#       2022년01월_계_100세 이상
# 0                   1683
# 1                     35
# 2                      2
# 3                      1
# 4                      2
# ...                  ...
# 3865                   4
# 3866                   5
# 3867                   3
# 3868                   4
# 3869                   0
#
# [3870 rows x 104 columns]

# %%
# 3번 행(사직동 행), cols 컬럼을 선택하여 temp에 저장하세요.
temp = df.loc[3,cols]
temp
# Out:
# 2022년01월_계_0세         42
# 2022년01월_계_1세         25
# 2022년01월_계_2세         44
# 2022년01월_계_3세         35
# 2022년01월_계_4세         52
#                       ..
# 2022년01월_계_96세         8
# 2022년01월_계_97세         4
# 2022년01월_계_98세         2
# 2022년01월_계_99세         2
# 2022년01월_계_100세 이상     1
# Name: 3, Length: 101, dtype: object

# %%
# 두 지역의 각 열 별 차이를 구하세요.
flag-temp
# Out:
# 2022년01월_계_0세         0
# 2022년01월_계_1세         0
# 2022년01월_계_2세         0
# 2022년01월_계_3세         0
# 2022년01월_계_4세         0
#                      ..
# 2022년01월_계_96세        0
# 2022년01월_계_97세        0
# 2022년01월_계_98세        0
# 2022년01월_계_99세        0
# 2022년01월_계_100세 이상    0
# Name: 2, Length: 101, dtype: object

# %%
# 위 결과의 값에 제곱을 하세요
# Out:
# 2022년01월_계_0세           0
# 2022년01월_계_1세         729
# 2022년01월_계_2세          81
# 2022년01월_계_3세         484
# 2022년01월_계_4세         225
#                      ...
# 2022년01월_계_96세          9
# 2022년01월_계_97세          4
# 2022년01월_계_98세          1
# 2022년01월_계_99세          0
# 2022년01월_계_100세 이상      1
# Length: 101, dtype: object

# %%
# 위 결과의 값을 모두 더하세요. (효자동과 사직동의 error)
# Out:
# 125072

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## 효자동과 다른 동네의 인구 분포 차이
# - 위와 같은 방법으로 효자동을 기준으로 다른 동네와의 error를 구하여 result 리스트에 추가하세요.

# %%
result = []
flag = df.loc[2, cols]
for i in range(len(df)) :
    # code here
    error = ((flag-df.loc[i, cols])**2).sum()
    result.append(error)


result
# Out:
# [1182379033357,
#  232502184,
#  0,
#  125072,
#  1171780,
#  92904,
#  577295,
#  215391,
#  78206,
#  795496,
#  406460,
#  675289,
#  408263,
#  930736,
#  700364,
#  312774,
#  403578,
#  499299,
#  329715,
#  164995430,
#  1181687,
#  725084,
#  1064304,
#  848802,
#  763638,
#  642722,
#  1345442,
#  319147,
#  224424,
#  428965,
#  158424,
#  119060,
#  94938,
#  361118,
#  101447,
#  593218052,
#  458949,
#  198944,
#  353395,
#  1447391,
#  689340,
#  98832,
#  116951,
#  89377,
#  2251715,
#  2543056,
#  251406,
#  472230,
#  200801,
#  1241426,
#  83673,
#  215589,
#  999059097,
#  432076,
#  3237044,
#  1837328,
#  1343389,
#  152017,
#  1754724,
#  198908,
#  250495,
#  1791342,
#  237975,
#  3065126,
#  543956,
#  147774,
#  529197,
#  183839,
#  142572,
#  212801,
#  1500359657,
#  9751553,
#  1769614,
#  583113,
#  1789916,
#  536042,
#  4327557,
#  355545,
#  8393372,
#  2022558,
#  2448663,
#  3461538,
#  896300,
#  2468083,
#  2944295,
#  4026840,
#  1393796460,
#  7055174,
#  2615462,
#  4117240,
#  625208,
#  4278311,
#  3680071,
#  9715771,
#  5725211,
#  1084557,
#  578518,
#  587396,
#  2741512,
#  1376414,
#  886160,
#  1896430581,
#  2400180,
#  843158,
#  304315,
#  7248950,
#  1677411,
#  2726743,
#  2177379,
#  2332465,
#  1073888,
#  2987265,
#  6792142,
#  848193,
#  6204054,
#  533810,
#  9183899,
#  1068940,
#  2257547265,
#  425033,
#  1867547,
#  1077689,
#  199359,
#  2005596,
#  1575976,
#  348630,
#  544391,
#  1707033,
#  454697,
#  2256738,
#  8580354,
#  369308,
#  9280615,
#  2715813,
#  948147,
#  2152882,
#  191701,
#  342865,
#  7412120,
#  1079496672,
#  2004107,
#  1639555,
#  4388690,
#  3336528,
#  5395490,
#  853709,
#  415982,
#  547747,
#  1275136,
#  1364924,
#  2236536,
#  1133302,
#  4758906,
#  1218160853,
#  2199658,
#  4099423,
#  163347,
#  2947435,
#  2358109,
#  1599762,
#  3246603,
#  1341028,
#  773326,
#  453580,
#  734051,
#  4076876,
#  1090600,
#  3196766,
#  3221059684,
#  1426786,
#  2960362,
#  4270244,
#  8835154,
#  11646041,
#  3305549,
#  1468505,
#  3144646,
#  5290804,
#  972678,
#  6307245,
#  9373024,
#  1145761,
#  2878453,
#  2161381,
#  5737864,
#  1978408,
#  1039601,
#  743028,
#  2760303367,
#  8473835,
#  9451700,
#  3756951,
#  1654199,
#  3710043,
#  5580348,
#  3618560,
#  5998485,
#  4004525,
#  2306682,
#  15135859,
#  3209849,
#  1051801,
#  243070,
#  107453,
#  25553650,
#  1116602328,
#  401280,
#  367786,
#  1213923,
#  4928057,
#  8530503,
#  1843803,
#  343005,
#  145724,
#  1618430,
#  2969881,
#  433140,
#  4172659,
#  527679,
#  5298007,
#  1730071794,
#  2900160,
#  9444018,
#  1233292,
#  1586085,
#  574828,
#  471000,
#  1644677,
#  2919708,
#  4541495,
#  983557,
#  1267368,
#  677190,
#  637576,
#  928106,
#  10762856,
#  5087027,
#  2494517244,
#  6230395,
#  5070198,
#  1729632,
#  3018015,
#  14304895,
#  1368913,
#  1128222,
#  324333,
#  551733,
#  202852,
#  221656,
#  1072135,
#  1303610,
#  1143510,
#  18860193,
#  6388768,
#  2616324,
#  3985527,
#  4245114280,
#  12659643,
#  4369571,
#  1218565,
#  4982571,
#  26625643,
#  606151,
#  1462423,
#  1247049,
#  8018704,
#  3082686,
#  2511299,
#  13080774,
#  713548,
#  616389,
#  8468946,
#  13345972,
#  5335092,
#  12705243,
#  2080849,
#  1829629,
#  1930876128,
#  8164604,
#  1314247,
#  2419982,
#  2773060,
#  1122221,
#  5000422,
#  315712,
#  1588533,
#  2954586,
#  6587219,
#  4899041,
#  1147850,
#  2279653,
#  8972903,
#  1888888,
#  1082832,
#  670844674,
#  6534781,
#  18256183,
#  1033852,
#  2861140,
#  451084,
#  6291150,
#  1251163,
#  148477,
#  1237966,
#  898101,
#  1821291078,
#  1388827,
#  10099175,
#  5518114,
#  1692519,
#  11914949,
#  744700,
#  6165251,
#  1431583,
#  2531831,
#  1046892,
#  427108,
#  86852,
#  95061,
#  948643,
#  1054238,
#  224320,
#  205391,
#  1778253,
#  1859544375,
#  5966281,
#  316649,
#  15479886,
#  3693087,
#  2556063,
#  4151753,
#  5096406,
#  3417952,
#  3507154,
#  2191204,
#  329454,
#  219637,
#  9399204,
#  1721211,
#  1543700,
#  3448032705,
#  2946655,
#  206102,
#  3860687,
#  7689482,
#  2595711,
#  16661324,
#  6343387,
#  1558463,
#  4333718,
#  1437789,
#  4442194,
#  1580253,
#  3355838,
#  3446390,
#  9062642,
#  223108,
#  1432922,
#  3900013,
#  1684912,
#  4932566,
#  3381427,
#  2090581238,
#  1166206,
#  3297956,
#  6236916,
#  5284081,
#  3304041,
#  1376136,
#  7727960,
#  767582,
#  1758707,
#  788991,
#  1238183,
#  406454,
#  823566,
#  676882,
#  1849723,
#  12663438,
#  1838723,
#  573624,
#  3610506422,
#  245824,
#  3157844,
#  1683939,
#  2615359,
#  2691530,
#  52405,
#  5410401,
#  4233973,
#  9869939,
#  1418554,
#  14667428,
#  10011835,
#  1319102,
#  6551357,
#  433698,
#  3797095,
#  2062723,
#  12890968,
#  2075309,
#  297386,
#  513572,
#  711538,
#  5540749014,
#  170515,
#  2428176,
#  106662,
#  872809,
#  896625,
#  967167,
#  288024,
#  5205794,
#  744606,
#  9595511,
#  3236396,
#  810746,
#  7096298,
#  6142863,
#  3314596,
#  3661122,
#  5670450,
#  1214852,
#  6390486,
#  4266719,
#  12990838,
#  5010235,
#  9711151,
#  6852262,
#  1707544,
#  387325,
#  157940,
#  2664227501,
#  5695214,
#  10971218,
#  102445,
#  2718198,
#  614225,
#  2834241,
#  1809208,
#  7139048,
#  297811,
#  637144,
#  3381443,
#  7126714,
#  3882025,
#  980536,
#  2551436,
#  1950880,
#  16569313,
#  1778716,
#  2328726,
#  142905747981,
#  12549318,
#  1067291,
#  1155891,
#  498824,
#  217190,
#  787867,
#  1554196,
#  1566317,
#  720783,
#  459629,
#  113129674,
#  564148,
#  430641,
#  318244,
#  87340,
#  247138,
#  280216,
#  329867,
#  588765,
#  873358,
#  209096,
#  785461,
#  408751,
#  283067,
#  76989169,
#  654579,
#  624529,
#  227785,
#  603799,
#  831210,
#  254982,
#  949919,
#  702087,
#  222953,
#  362442,
#  284443,
#  796650,
#  133424254,
#  319002,
#  888770,
#  357002,
#  460759,
#  487009,
#  310949,
#  553163,
#  735352,
#  3735646,
#  998183,
#  456865,
#  1512803665,
#  895906,
#  185562,
#  1129280,
#  1659975,
#  1003941,
#  400585,
#  2159946,
#  1399286,
#  1679356,
#  606367,
#  2023747,
#  133276,
#  125821,
#  1035496,
#  500355,
#  547114,
#  145476,
#  4178385,
#  369640,
#  1273936,
#  853492389,
#  5456888,
#  315150,
#  2532731,
#  1439258,
#  690998,
#  9541546,
#  60993,
#  3807762,
#  519388,
#  342430,
#  3270774,
#  276988,
#  423445,
#  792346162,
#  675878,
#  6615952,
#  127153,
#  442144,
#  279604,
#  14178396,
#  469438,
#  283305,
#  244627,
#  239629,
#  250813,
#  469642,
#  320331,
#  181872,
#  259176,
#  246423,
#  326101,
#  981001142,
#  640012,
#  3072072,
#  1395728,
#  9706528,
#  12722955,
#  572463,
#  4525487,
#  299368,
#  271814,
#  224219,
#  631876,
#  3040055,
#  1047193,
#  1905280293,
#  1652844,
#  4730261,
#  3978842,
#  3402901,
#  358627,
#  622385,
#  5619660,
#  326293,
#  1847927,
#  213657,
#  7092229,
#  298440,
#  358405,
#  373102,
#  533144,
#  2723774,
#  9762232,
#  2681079,
#  1139359215,
#  980638,
#  264303,
#  274617,
#  150725,
#  3169055,
#  1505939,
#  3009758,
#  588728,
#  448159,
#  88643,
#  3431611,
#  9799462,
#  3655904,
#  180248,
#  1080332,
#  670536,
#  607070960,
#  692241,
#  354306,
#  378689,
#  455167,
#  387634,
#  622880,
#  294639,
#  289330,
#  2242391,
#  2731698,
#  1233972,
#  274205,
#  4554527,
#  898463,
#  6081384,
#  1533071,
#  247740953,
#  614435,
#  409446,
#  948708,
#  34117080,
#  7329883,
#  1262412,
#  9070581,
#  906497,
#  489811749,
#  4049760,
#  98591,
#  218610,
#  123831,
#  466840,
#  1132634,
#  186360,
#  572107,
#  931377,
#  522287,
#  176290,
#  7404925,
#  344698610,
#  142344,
#  94941,
#  480870,
#  3465204,
#  133495,
#  3503603,
#  769067,
#  315205,
#  120782,
#  3890670,
#  533267161,
#  595482,
#  4304496,
#  549600,
#  233828,
#  271513,
#  2536987,
#  412271,
#  425046,
#  1934826,
#  194845,
#  4155784,
#  3467538,
#  350939954,
#  21979006,
#  316183,
#  76387295,
#  3035970,
#  438816,
#  72446269295,
#  49949605,
#  305111,
#  545548,
#  762390,
#  800032,
#  722011,
#  296505,
#  695507,
#  425310,
#  409958,
#  83351,
#  375219,
#  1325260,
#  1378219873,
#  268889,
#  106386,
#  149771,
#  209637,
#  525715,
#  145394,
#  48644,
#  305021,
#  388401,
#  179895,
#  871505,
#  1311640,
#  455348,
#  452230,
#  1036538,
#  428970,
#  11864837,
#  185709,
#  1497141,
#  3882229,
#  1782912,
#  1487142,
#  328007162,
#  291805,
#  294211,
#  584351,
#  266274,
#  370127,
#  258312,
#  579194,
#  383983,
#  284677,
#  346319,
#  270059,
#  270238,
#  748337,
#  1341399,
#  890016,
#  1222599,
#  371615,
#  224450746,
#  106645,
#  210786,
#  109324,
#  440295,
#  135604,
#  199367,
#  211633,
#  221756,
#  501103,
#  143704,
#  359538,
#  244532,
#  314511,
#  2371159876,
#  685779,
#  1817702,
#  850047,
#  806651,
#  893850,
#  403513,
#  149414,
#  432518,
#  291731,
#  571664,
#  534986,
#  4971176,
#  478388,
#  8570279,
#  8802913,
#  1734813,
#  2373570,
#  8637567,
#  576469,
#  3507760,
#  4708980,
#  253786,
#  4734108,
#  2139412187,
#  459138,
#  234523,
#  505613,
#  2545375,
#  1605542,
#  94836,
#  1766530,
#  586355,
#  137425,
#  232116,
#  2711732,
#  77273,
#  61568,
#  371498,
#  143735,
#  195615,
#  1616634,
#  800303,
#  402111,
#  516038,
#  5505264,
#  3855488,
#  6601107,
#  3771691491,
#  1865859,
#  376831,
#  269917,
#  3208010,
#  264030,
#  508490,
#  5883530,
#  4892529,
#  2441526,
#  652802,
#  6895956,
#  1282322,
#  12754871,
#  677378,
#  21039351,
#  9920276,
#  8390971,
#  1254795,
#  472237,
#  8358920,
#  1123644,
#  892223,
#  161119,
#  823294084,
#  17391049,
#  740980,
#  223978,
#  21398871,
#  12541078,
#  6686947,
#  2682885,
#  1979837,
#  456992,
#  1025142,
#  1492979,
#  113415101061,
#  229017815,
#  534378,
#  665314,
#  95248,
#  873949,
#  1021609,
#  579017,
#  425122,
#  917735,
#  19078297,
#  9047163,
#  938763,
#  1818845,
#  1818845,
#  31380133,
#  364375,
#  540758,
#  356289,
#  83271,
#  952397,
#  1400030,
#  1155244,
#  317329,
#  449438,
#  476363,
#  1114351,
#  2032566060,
#  198424,
#  212196,
#  326053,
#  1087618,
#  589087,
#  355875,
#  17209036,
#  5650214,
#  631891,
#  1886899,
#  6274318,
#  2120229,
#  458021,
#  202142,
#  265008,
#  1264405,
#  1458927,
#  177506,
#  1287793,
#  255285,
#  188975,
#  1927909034,
#  873447,
#  1119603,
#  719081,
#  1070030,
#  1415089,
#  437279,
#  2836769,
#  2841864,
#  749409,
#  917051,
#  10239774,
#  12003516,
#  22811159,
#  3981222,
#  15503037,
#  3387740405,
#  5481728,
#  7868316,
#  6670448,
#  317290,
#  1316226,
#  1435140,
#  3673944,
#  4292976,
#  601021,
#  2240661,
#  579637,
#  1250447,
#  455379,
#  2381691,
#  1008297,
#  12458481,
#  1446166,
#  5686094,
#  6059321,
#  13596487,
#  3002201820,
#  8720777,
#  236537,
#  141365,
#  9623811,
#  6108449,
#  264321,
#  125859,
#  5277483,
#  1590937,
#  588926,
#  358564,
#  7793130,
#  538433,
#  895570,
#  6416960,
#  4672837,
#  484602,
#  1018571,
#  5315140,
#  130066,
#  176343,
#  2117604,
#  1127366517,
#  3789164,
#  4577210,
#  1263664,
#  640138,
#  1414225,
#  2511585,
#  3996598,
#  1264984,
#  8103393,
#  1362879,
#  6929762,
#  2872912,
#  4020842725,
#  16808673,
#  12492362,
#  6782742,
#  22075494,
#  7348226,
#  4860268,
#  447037,
#  217126,
#  2016339,
#  226281,
#  257094,
#  5630604,
#  144178,
#  1128573,
#  625786,
#  125402,
#  6329080,
#  1784613,
#  2694576,
#  3980997,
#  2695769,
#  1927303,
#  2125176,
#  1818845,
#  49036673,
#  1688587,
#  364678,
#  869897,
#  556293,
#  915319,
#  945802,
#  1154579,
#  1020994,
#  1385489,
#  1109193,
#  1215387,
#  1309691,
#  1725247,
#  1752628,
#  1651982,
#  1516578,
#  1556253,
#  706009,
#  1499916,
#  1761408,
#  1367201,
#  510665,
#  1571579,
#  1719754,
#  1269754,
#  ...]

# %%
# result 리스트를 pd.Series로 변환하세요.
# Out:
# 0       1182379033357
# 1           232502184
# 2                   0
# 3              125072
# 4             1171780
#             ...
# 3865           105116
# 3866           250581
# 3867           171922
# 3868            33522
# 3869           869752
# Length: 3870, dtype: int64

# %%
# 값을 기준으로 정렬하세요.
# Out:
# 2                   0
# 3868            33522
# 695             48644
# 387             52405
# 3197            57932
#             ...
# 827      113415101061
# 3487     139019226541
# 452      142905747981
# 0       1182379033357
# 1276    2406921199175
# Length: 3870, dtype: int64

# %%
# 3868 행을 조회하세요.
# Out:
# 33522

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>

# %% [markdown]
# ## (참고) 시각화

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize = (16,6))

plt.plot(flag, label = '효자동')
plt.plot(df.loc[3868, cols], label = '중문동')
plt.legend()
plt.xticks('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 8
#       6 plt.plot(df.loc[3868, cols], label = '중문동')
#       7 plt.legend()
# ----> 8 plt.xticks('')
#       9 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2237, in xticks(ticks, labels, minor, **kwargs)
#    2234         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    2235                         "without setting 'ticks'")
#    2236 else:
# -> 2237     locs = ax.set_xticks(ticks, minor=minor)
#    2239 labels_out: list[Text] = []
#    2240 if labels is None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:2229, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2224     first_key = next(iter(kwargs))
#    2225     raise ValueError(
#    2226         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2227         "other than 'minor' modify the text labels and can only be used if "
#    2228         "'labels' are passed as well.")
# -> 2229 result = self._set_tick_locations(ticks, minor=minor)
#    2230 if labels is not None:
#    2231     self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:2170, in Axis._set_tick_locations(self, ticks, minor)
#    2165 def _set_tick_locations(self, ticks, *, minor=False):
#    2166     # see docstring of set_ticks
#    2167
#    2168     # XXX if the user changes units, the information will be lost here
#    2169     ticks = self.convert_units(ticks)
# -> 2170     locator = mticker.FixedLocator(ticks)  # validate ticks early.
#    2171     if len(ticks):
#    2172         for axis in self._get_shared_axis():
#    2173             # set_view_interval maintains any preexisting inversion.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\ticker.py:1779, in FixedLocator.__init__(self, locs, nbins)
#    1777 def __init__(self, locs, nbins=None):
#    1778     self.locs = np.asarray(locs)
# -> 1779     _api.check_shape((None,), locs=self.locs)
#    1780     self.nbins = max(nbins, 2) if nbins is not None else None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:162, in check_shape(shape, **kwargs)
#     159 if len(shape) == 1:
#     160     text_shape += ","
# --> 162 raise ValueError(
#     163     f"{k!r} must be {len(shape)}D with shape ({text_shape}), "
#     164     f"but your input has shape {v.shape}"
#     165 )
#
# ValueError: 'locs' must be 1D with shape (N,), but your input has shape ()
